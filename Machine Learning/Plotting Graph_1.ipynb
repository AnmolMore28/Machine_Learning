# %%
import pandas as pd

# %%
df = pd.read_csv('1. Regression - Module - (Housing Prices).csv')

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['Sale Price'], color = 'orange')
plt.xlabel('Record Number')
plt.ylabel('Sale Price')
plt.title('My First Graph')
plt.show()

# %%
plt.plot(df['Sale Price'],marker='o', markerfacecolor="red",markersize="5",color ='orange',linewidth ='5',linestyle='dashed')

# %%
df.groupby('Condition of the House')['ID'].count()
# Out:
# Condition of the House
# Bad             30
# Excellent     1701
# Fair         14031
# Good          5679
# Okay           172
# Name: ID, dtype: int64

# %%
values =(30,1701,14031,5679,172)

# %%
labels =('Bad','Excellent','Fair','Good', 'Okay')

# %%
plt.pie(values, labels = labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x207f0734050>,
# ...
#  [Text(1.099989541385049, 0.004796753434368107, 'Bad'),
#   Text(1.0641591373844368, 0.27850553014475643, 'Excellent'),
#   Text(-0.9085709380486652, 0.620079713047741, 'Fair'),
#   Text(0.7046888223897579, -0.8446381850229934, 'Good'),
#   Text(1.0996562341282203, -0.02749848619362501, 'Okay')])

# %%
plt.bar(labels, values, color ='Orange')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar( labels,values, color = 'red', linewidth = '5', linestyle = 'dashed')
plt.xlabel("Condition of House")
plt.ylabel("Count Of House")
plt.title("My First Graph")
plt.show()
